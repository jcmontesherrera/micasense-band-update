# %% [markdown]
# # Multispectral Band Analysis
#
# This notebook analyzes multispectral band metadata to identify differences in band naming and assignment across firmware versions.

# %%
# Set up Python path to find the toolbox module
import sys
import os
from pathlib import Path

# Get the current notebook's directory and add its parent to the path
notebook_dir = Path(os.getcwd())
sys.path.append(str(notebook_dir))

# Import the toolbox module
from toolbox import plots
import pandas as pd

# Check if the module has the required function
print("Available functions in plots module:", [f for f in dir(plots) if not f.startswith('_')])
# Out:
# Available functions in plots module: ['DEFAULT_FIELDS', 'Path', 'compare_band_assignments', 'create_band_table', 'datetime', 'extract_metadata', 'extract_multispec_analysis', 'extract_multispec_bands', 'extract_tif_metadata', 'filter_date', 'filter_plot', 'filter_year', 'info', 'json', 'monthly', 'os', 'parse_directory_structure', 'parse_plots', 'pd', 're', 'recent', 'subprocess', 'yearly']

# %% [markdown]
# ## Step 1: Parse Plot Directory Structure

# %%
# Parse the directory structure - adjust path to your data location
base_path = r"D:\TERN-Dronescape"  # Adjust to your data path
df = plots.parse_directory_structure(base_path)

# Preview the initial DataFrame
print(f"Found {len(df)} plot visits")
df.head()
# Out:
# Found 208 plot visits
#       plot_id visit_date                               full_path
# 0  NTABRT0001 2024-08-29  D:\TERN-Dronescape\NTABRT0001\20240829
# 1  NTABRT0002 2024-08-29  D:\TERN-Dronescape\NTABRT0002\20240829
# 2  NTABRT0003 2024-08-29  D:\TERN-Dronescape\NTABRT0003\20240829
# 3  NTABRT0004 2024-08-28  D:\TERN-Dronescape\NTABRT0004\20240828
# 4  NTABRT0005 2024-08-28  D:\TERN-Dronescape\NTABRT0005\20240828

# %% [markdown]
# ## Step 2: Extract Multispectral Band Metadata
#
# This step will extract metadata from all multispectral bands in each plot directory. This may take some time to complete depending on the number of plots and images.

# %%
# First, check if exiftool is installed and working
import subprocess

try:
    result = subprocess.run(['exiftool', '-ver'], capture_output=True, text=True)
    if result.returncode == 0:
        print(f"exiftool is installed, version: {result.stdout.strip()}")
    else:
        print("exiftool command failed with return code", result.returncode)
        print("Make sure exiftool is installed and in your PATH")
except Exception as e:
    print(f"Error running exiftool: {e}")
    print("You need to install exiftool for this script to work.")
    print("Visit https://exiftool.org/ for installation instructions")

### --- Split here --- ###

# Fields we want to extract
fields = ['FileName', 'BandName', 'CentralWavelength', 'CenterWavelength', 'WavelengthFWHM', 'Bandwidth', 'RigCameraIndex', 'RigRelativesReferenceRigCameraIndex', 'Software', 'SwVersion']

# Run the extraction with the updated fields list
raw_bands_df = plots.extract_multispec_analysis(df, fields=fields, max_band_number=11)

# Create a new DataFrame with adjusted band numbering
bands_df = raw_bands_df.copy()

# Rename columns from Band0_X to Band1_X, etc.
renamed_columns = {}
for col in raw_bands_df.columns:
    # Check if it's a band metadata column
    if col.startswith('Band') and '_' in col:
        band_part, field_part = col.split('_', 1)
        if band_part.startswith('Band'):
            # Extract the band number and increment it by 1
            band_num = int(band_part.replace('Band', ''))
            new_band_num = band_num
            new_col = f"Band{new_band_num}_{field_part}"
            renamed_columns[col] = new_col
        
# Rename the columns in the DataFrame
bands_df = bands_df.rename(columns=renamed_columns)

# Add a new column for each band with the file suffix (last 6 characters)
for idx, row in bands_df.iterrows():
    # Look through columns that contain band file names
    for col in bands_df.columns:
        if col.startswith('Band') and col.endswith('_FileName'):
            # Get band number from column name
            band_num = col.split('_')[0]
            # If we have a filename, extract the last 6 characters
            if pd.notna(row[col]):
                filename = row[col]
                # Extract the last 6 characters (likely includes the extension)
                file_suffix = filename[-6:] if len(filename) >= 6 else filename
                # Create a new column for the suffix
                suffix_col = f"{band_num}_FileSuffix"
                bands_df.loc[idx, suffix_col] = file_suffix

# Show the DataFrame columns to see what we collected
print(f"Columns in the result DataFrame:")
print(bands_df.columns.tolist())

# Preview the data
bands_df.head()
# Out:
# exiftool is installed, version: 12.84
# Extracting multispectral band metadata for 208 plot visits...
# Fields to extract: FileName, BandName, CentralWavelength, CenterWavelength, WavelengthFWHM, Bandwidth, RigCameraIndex, RigRelativesReferenceRigCameraIndex, Software, SwVersion
# Looking for bands 1 through 11
# Processing NTABRT0001/20240829 (1/208)
# Searching for TIF files in: D:\TERN-Dronescape\NTABRT0001\20240829\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\NTABRT0002\20240829\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\NTABRT0003\20240829\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\NTABRT0004\20240828\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\NTABRT0005\20240828\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Processing NTABRT0006/20240828 (6/208)
# Searching for TIF files in: D:\TERN-Dronescape\NTABRT0006\20240828\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\NTABRT0007\20240828\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\NTABRT0009\20240829\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\NTAFIN0001\20240902\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\NTAFIN0002\20240901\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Processing NTAFIN0003/20240902 (11/208)
# Searching for TIF files in: D:\TERN-Dronescape\NTAFIN0003\20240902\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Progress: 10/208 plots processed (4.8%)
# Searching for TIF files in: D:\TERN-Dronescape\NTAFIN0004\20240902\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\NTAFIN0005\20240902\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\NTAFIN0006\20240902\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\NTAFIN0007\20240831\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Processing NTAFIN0008/20240831 (16/208)
# Searching for TIF files in: D:\TERN-Dronescape\NTAFIN0008\20240831\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\NTAFIN0009\20240901\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\NTAFIN0010\20240901\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\NTAFIN0011\20240901\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\NTAFIN0012\20240924\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Processing NTAFIN0013/20240925 (21/208)
# Searching for TIF files in: D:\TERN-Dronescape\NTAFIN0013\20240925\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Progress: 20/208 plots processed (9.6%)
# Searching for TIF files in: D:\TERN-Dronescape\NTAFIN0014\20240925\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\NTAFIN0017\20240924\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\NTAFIN0018\20240924\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\NTAFIN0019\20240924\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Processing NTAFIN0024/20240926 (26/208)
# Searching for TIF files in: D:\TERN-Dronescape\NTAFIN0024\20240926\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\NTAFIN0025\20240926\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\NTAFIN0026\20240830\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\NTAFIN0027\20240830\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\NTAFIN0028\20240927\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Processing NTAFIN0029/20240927 (31/208)
# Searching for TIF files in: D:\TERN-Dronescape\NTAFIN0029\20240927\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Progress: 30/208 plots processed (14.4%)
# Searching for TIF files in: D:\TERN-Dronescape\NTAFIN0030\20240927\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\NTAFIN0031\20240927\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\NTAFIN0032\20240830\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\NTAFIN0033\20240830\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Processing NTAMAC0001/20240831 (36/208)
# Searching for TIF files in: D:\TERN-Dronescape\NTAMAC0001\20240831\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\NTAMAC0002\20240831\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\NTAMAC0003\20240831\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\SAAEYB0004\20240722\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\SAAEYB0005\20240722\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Processing SAAEYB0006/20240723 (41/208)
# Searching for TIF files in: D:\TERN-Dronescape\SAAEYB0006\20240723\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Progress: 40/208 plots processed (19.2%)
# Searching for TIF files in: D:\TERN-Dronescape\SAAEYB0007\20240721\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\SAAEYB0008\20240723\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\SAAEYB0009\20240720\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\SAAEYB0010\20240721\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Processing SAAEYB0011/20240723 (46/208)
# Searching for TIF files in: D:\TERN-Dronescape\SAAEYB0011\20240723\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\SAAEYB0012\20240722\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\SAAEYB0013\20240718\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\SAAEYB0014\20240720\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\SAAEYB0015\20240721\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Processing SAAEYB0017/20240720 (51/208)
# Searching for TIF files in: D:\TERN-Dronescape\SAAEYB0017\20240720\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Progress: 50/208 plots processed (24.0%)
# Searching for TIF files in: D:\TERN-Dronescape\SAAEYB0018\20240723\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\SAAEYB0019\20240722\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\SAAEYB0020\20240717\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\SAAEYB0037\20240717\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Processing SAAGAW0004/20241001 (56/208)
# Searching for TIF files in: D:\TERN-Dronescape\SAAGAW0004\20241001\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\SAAGAW0005\20241001\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\SAAGAW0006\20241002\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\SAAGAW0007\20241002\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\SAAGAW0008\20241001\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Processing SAAGAW0009/20241001 (61/208)
# Searching for TIF files in: D:\TERN-Dronescape\SAAGAW0009\20241001\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Progress: 60/208 plots processed (28.8%)
# Searching for TIF files in: D:\TERN-Dronescape\SAAGVD0005\20240928\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\SAAGVD0006\20240928\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\SAAKAN0001\20241208\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\SAAKAN0002\20241210\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Processing SAAKAN0003/20241209 (66/208)
# Searching for TIF files in: D:\TERN-Dronescape\SAAKAN0003\20241209\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\SAAKAN0004\20241210\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\SAAKAN0005\20241210\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\SAAKAN0006\20241211\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\SAAKAN0007\20241211\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Processing SAAKAN0008/20241208 (71/208)
# Searching for TIF files in: D:\TERN-Dronescape\SAAKAN0008\20241208\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Progress: 70/208 plots processed (33.7%)
# Searching for TIF files in: D:\TERN-Dronescape\SAAKAN0009\20241208\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\SAAKAN0010\20241207\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\SAAKAN0011\20241207\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\SAAKAN0012\20241207\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Processing SAAKAN0013/20241211 (76/208)
# Searching for TIF files in: D:\TERN-Dronescape\SAAKAN0013\20241211\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\SAANCP0001\20241122\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\SAANCP0002\20241121\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\SAANCP0003\20241121\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\SAANCP0004\20241121\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Processing SAANCP0005/20241121 (81/208)
# Searching for TIF files in: D:\TERN-Dronescape\SAANCP0005\20241121\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Progress: 80/208 plots processed (38.5%)
# Searching for TIF files in: D:\TERN-Dronescape\SAANCP0006\20241120\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\SAANCP0007\20241120\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\SAANCP0008\20241118\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\SAANCP0009\20241119\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Processing SAASTP0033/20241002 (86/208)
# Searching for TIF files in: D:\TERN-Dronescape\SAASTP0033\20241002\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\SAASTP0034\20241002\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\SAASTP0036\20240928\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\SAASTP0037\20240929\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\SAASVP0001\20241120\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Processing SAASVP0002/20241120 (91/208)
# Searching for TIF files in: D:\TERN-Dronescape\SAASVP0002\20241120\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Progress: 90/208 plots processed (43.3%)
# Searching for TIF files in: D:\TERN-Dronescape\SASMDD0001\20240312\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 10 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\SASMDD0002\20240312\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 10 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\SASMDD0003\20240312\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 10 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\SASMDD0008\20240313\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 5 bands with RigCameraIndex
# Processing SASMDD0009/20240313 (96/208)
# Searching for TIF files in: D:\TERN-Dronescape\SASMDD0009\20240313\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 10 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\SASMDD0010_18\20240311\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 10 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\SASMDD0011\20240314\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 10 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\SASMDD0012\20240314\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 10 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\SASMDD0013\20240310\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 10 bands with RigCameraIndex
# Processing SASMDD0014/20240313 (101/208)
# Searching for TIF files in: D:\TERN-Dronescape\SASMDD0014\20240313\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 5 bands with RigCameraIndex
# Progress: 100/208 plots processed (48.1%)
# Searching for TIF files in: D:\TERN-Dronescape\SASMDD0016_17\20240315\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 5 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\SASMDD005_6\20240314\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 5 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\SASRIV0001\20240313\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 10 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\SASRIV0002\20240315\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 10 bands with RigCameraIndex
# Processing WAAAVW0003/20250405 (106/208)
# Searching for TIF files in: D:\TERN-Dronescape\WAAAVW0003\20250405\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\WAAAVW0004\20250405\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\WAAAVW0008\20250405\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\WAACOO0020\20250823\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\WAACOO0020\20250826
# No files with _N.tif pattern found, looking for any TIF files...
# No TIF files found
# Processing WAACOO0021/20250822 (111/208)
# Searching for TIF files in: D:\TERN-Dronescape\WAACOO0021\20250822\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Progress: 110/208 plots processed (52.9%)
# Searching for TIF files in: D:\TERN-Dronescape\WAACOO0021\20250826
# No files with _N.tif pattern found, looking for any TIF files...
# No TIF files found
# Searching for TIF files in: D:\TERN-Dronescape\WAACOO0022\20250822\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\WAACOO0023\20250822\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\WAACOO0024\20250824\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Processing WAACOO0025/20250824 (116/208)
# Searching for TIF files in: D:\TERN-Dronescape\WAACOO0025\20250824\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\WAACOO0034\20250827\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\WAACOO0039\20250823\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\WAACOO0040\20250823\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\WAACOO0041\20250823\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Processing WAACOO0042/20250822 (121/208)
# Searching for TIF files in: D:\TERN-Dronescape\WAACOO0042\20250822\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Progress: 120/208 plots processed (57.7%)
# Searching for TIF files in: D:\TERN-Dronescape\WAACOO0043\20250822\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\WAACOO0044\20250822\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\WAAESP0001\20250328\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\WAAJAF0001\20250329\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Processing WAAJAF0002/20250329 (126/208)
# Searching for TIF files in: D:\TERN-Dronescape\WAAJAF0002\20250329\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\WAAJAF0003\20250328\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\WAAJAF0007\20250404\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\WAAJAF0009\20250404\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\WAAJAF0010\20250404\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Processing WAAPIL0001/20250529 (131/208)
# Searching for TIF files in: D:\TERN-Dronescape\WAAPIL0001\20250529\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Progress: 130/208 plots processed (62.5%)
# Searching for TIF files in: D:\TERN-Dronescape\WAAPIL0002\20250701\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\WAAPIL0003\20250701\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\WAAPIL0004\20250702\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\WAAPIL0005\20250701\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Processing WAAPIL0006/20250701 (136/208)
# Searching for TIF files in: D:\TERN-Dronescape\WAAPIL0006\20250701\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\WAAPIL0007\20250701\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\WAAPIL0008\20250630\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\WAAPIL0009\20250630\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\WAAPIL0010\20250603\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Processing WAAPIL0011/20250603 (141/208)
# Searching for TIF files in: D:\TERN-Dronescape\WAAPIL0011\20250603\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Progress: 140/208 plots processed (67.3%)
# Searching for TIF files in: D:\TERN-Dronescape\WAAPIL0012\20250529\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\WAAPIL0014\20250529\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\WAAPIL0015\20250601\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\WAAPIL0016\20250530\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Processing WAAPIL0017/20250629 (146/208)
# Searching for TIF files in: D:\TERN-Dronescape\WAAPIL0017\20250629\imagery\multispec
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\WAAPIL0018\20250528\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\WAAPIL0019\20250528\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\WAAPIL0020\20250702\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\WAAPIL0021\20250702\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Processing WAAPIL0022/20250702 (151/208)
# Searching for TIF files in: D:\TERN-Dronescape\WAAPIL0022\20250702\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Progress: 150/208 plots processed (72.1%)
# Searching for TIF files in: D:\TERN-Dronescape\WAAPIL0023\20250629\imagery\multispec
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\WAAPIL0024\20250629\imagery\multispec
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\WAAPIL0025\20250726\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\WAAPIL0026\20250726\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Processing WAAPIL0027/20250726 (156/208)
# Searching for TIF files in: D:\TERN-Dronescape\WAAPIL0027\20250726\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\WAAPIL0028\20250726\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\WAAPIL0029\20250726\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\WAAPIL0030\20250727\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\WAAPIL0031\20250728\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Processing WAAPIL0032/20250728 (161/208)
# Searching for TIF files in: D:\TERN-Dronescape\WAAPIL0032\20250728\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Progress: 160/208 plots processed (76.9%)
# Searching for TIF files in: D:\TERN-Dronescape\WAAPIL0033\20250728\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\WAAPIL0034\20250727\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\WAAPIL0036\20250602\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\WAAPIL0037\20250601\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Processing WAAPIL0038/20250601 (166/208)
# Searching for TIF files in: D:\TERN-Dronescape\WAAPIL0038\20250601\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\WAAPIL0039\20250602\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\WAAPIL0040\20250531\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\WAAPIL0041\20250531\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\WAAPIL0042\20250530\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Processing WAAPIL0042/20250531 (171/208)
# Searching for TIF files in: D:\TERN-Dronescape\WAAPIL0042\20250531\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Progress: 170/208 plots processed (81.7%)
# Searching for TIF files in: D:\TERN-Dronescape\WAAPIL0043\20250604\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\WAAPIL0044\20250604\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\WAAPIL0045\20250604\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\WAAPIL0046\20250723\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Processing WAAPIL0047/20250723 (176/208)
# Searching for TIF files in: D:\TERN-Dronescape\WAAPIL0047\20250723\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\WAAPIL0048\20250724\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\WAAPIL0049\20250723\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\WAAPIL0050\20250723\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\WAAPIL0051\20250723\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Processing WAAPIL0052/20250625 (181/208)
# Searching for TIF files in: D:\TERN-Dronescape\WAAPIL0052\20250625\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Progress: 180/208 plots processed (86.5%)
# Searching for TIF files in: D:\TERN-Dronescape\WAAPIL0053\20250625\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\WAAPIL0054\20250626\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\WAAPIL0055\20250626\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\WAAPIL0056\20250626\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Processing WAAPIL0057/20250625 (186/208)
# Searching for TIF files in: D:\TERN-Dronescape\WAAPIL0057\20250625\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\WAAPIL0058\20250625\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\WAAPIL0059\20250626\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\WAAPIL0060\20250627\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\WAAPIL0061\20250627\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Processing WAAPIL0062/20250627 (191/208)
# Searching for TIF files in: D:\TERN-Dronescape\WAAPIL0062\20250627\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Progress: 190/208 plots processed (91.3%)
# Searching for TIF files in: D:\TERN-Dronescape\WAAPIL0063\20250627\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\WAAPIL0064\20250628\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\WAAPIL0065\20250628\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\WAAPIL0066\20250628\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Processing WAAPIL0071/20250725 (196/208)
# Searching for TIF files in: D:\TERN-Dronescape\WAAPIL0071\20250725\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\WAAPIL0072\20250725\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\WAAPIL0073\20250725\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\WAAPIL0074\20250725\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\WAAPIL0075\20250725\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Processing WAAPIL0076/20250725 (201/208)
# Searching for TIF files in: D:\TERN-Dronescape\WAAPIL0076\20250725\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Progress: 200/208 plots processed (96.2%)
# Searching for TIF files in: D:\TERN-Dronescape\WAASWA0012\20250326\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\WAASWA0013\20250326\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\WAASWA0014\20250326\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\WAFWAR0005\20250329\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Processing WAFWAR0007/20250330 (206/208)
# Searching for TIF files in: D:\TERN-Dronescape\WAFWAR0007\20250330\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Searching for TIF files in: D:\TERN-Dronescape\WAFWAR0008\20250330\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Processing WAGCOO0004/20250821 (208/208)
# Searching for TIF files in: D:\TERN-Dronescape\WAGCOO0004\20250821\imagery\multispec\level0_raw
# No files with _N.tif pattern found, looking for any TIF files...
# Found 11 TIF files
# Successfully extracted metadata for 11 files
# Found 11 bands with RigCameraIndex
# Successfully processed metadata for 206 of 208 plot visits
# Columns in the result DataFrame:
# ['plot_id', 'visit_date', 'full_path', 'Software', 'SwVersion', 'Band0_FileName', 'Band0_BandName', 'Band0_CentralWavelength', 'Band0_CenterWavelength', 'Band0_WavelengthFWHM', 'Band0_Bandwidth', 'Band0_RigRelativesReferenceRigCameraIndex', 'Band0_Software', 'Band0_SwVersion', 'Band9_FileName', 'Band9_BandName', 'Band9_CentralWavelength', 'Band9_CenterWavelength', 'Band9_WavelengthFWHM', 'Band9_Bandwidth', 'Band9_RigRelativesReferenceRigCameraIndex', 'Band9_Software', 'Band9_SwVersion', 'Band10_FileName', 'Band10_BandName', 'Band10_CentralWavelength', 'Band10_CenterWavelength', 'Band10_WavelengthFWHM', 'Band10_Bandwidth', 'Band10_RigRelativesReferenceRigCameraIndex', 'Band10_Software', 'Band10_SwVersion', 'Band1_FileName', 'Band1_BandName', 'Band1_CentralWavelength', 'Band1_CenterWavelength', 'Band1_WavelengthFWHM', 'Band1_Bandwidth', 'Band1_RigRelativesReferenceRigCameraIndex', 'Band1_Software', 'Band1_SwVersion', 'Band2_FileName', 'Band2_BandName', 'Band2_CentralWavelength', 'Band2_CenterWavelength', 'Band2_WavelengthFWHM', 'Band2_Bandwidth', 'Band2_RigRelativesReferenceRigCameraIndex', 'Band2_Software', 'Band2_SwVersion', 'Band3_FileName', 'Band3_BandName', 'Band3_CentralWavelength', 'Band3_CenterWavelength', 'Band3_WavelengthFWHM', 'Band3_Bandwidth', 'Band3_RigRelativesReferenceRigCameraIndex', 'Band3_Software', 'Band3_SwVersion', 'Band4_FileName', 'Band4_BandName', 'Band4_CentralWavelength', 'Band4_CenterWavelength', 'Band4_WavelengthFWHM', 'Band4_Bandwidth', 'Band4_RigRelativesReferenceRigCameraIndex', 'Band4_Software', 'Band4_SwVersion', 'Band5_FileName', 'Band5_BandName', 'Band5_CentralWavelength', 'Band5_CenterWavelength', 'Band5_WavelengthFWHM', 'Band5_Bandwidth', 'Band5_RigRelativesReferenceRigCameraIndex', 'Band5_Software', 'Band5_SwVersion', 'Band6_FileName', 'Band6_BandName', 'Band6_CentralWavelength', 'Band6_CenterWavelength', 'Band6_WavelengthFWHM', 'Band6_Bandwidth', 'Band6_RigRelativesReferenceRigCameraIndex', 'Band6_Software', 'Band6_SwVersion', 'Band7_FileName', 'Band7_BandName', 'Band7_CentralWavelength', 'Band7_CenterWavelength', 'Band7_WavelengthFWHM', 'Band7_Bandwidth', 'Band7_RigRelativesReferenceRigCameraIndex', 'Band7_Software', 'Band7_SwVersion', 'Band8_FileName', 'Band8_BandName', 'Band8_CentralWavelength', 'Band8_CenterWavelength', 'Band8_WavelengthFWHM', 'Band8_Bandwidth', 'Band8_RigRelativesReferenceRigCameraIndex', 'Band8_Software', 'Band8_SwVersion', 'Band0_FileSuffix', 'Band9_FileSuffix', 'Band10_FileSuffix', 'Band1_FileSuffix', 'Band2_FileSuffix', 'Band3_FileSuffix', 'Band4_FileSuffix', 'Band5_FileSuffix', 'Band6_FileSuffix', 'Band7_FileSuffix', 'Band8_FileSuffix']
#       plot_id visit_date                               full_path Software  \
# 0  NTABRT0001 2024-08-29  D:\TERN-Dronescape\NTABRT0001\20240829   v1.4.0
# 1  NTABRT0002 2024-08-29  D:\TERN-Dronescape\NTABRT0002\20240829   v1.4.0
# 2  NTABRT0003 2024-08-29  D:\TERN-Dronescape\NTABRT0003\20240829   v1.4.0
# 3  NTABRT0004 2024-08-28  D:\TERN-Dronescape\NTABRT0004\20240828   v1.4.0
# 4  NTABRT0005 2024-08-28  D:\TERN-Dronescape\NTABRT0005\20240828   v1.4.0
#
#   SwVersion  Band0_FileName Band0_BandName  Band0_CentralWavelength  \
# 0    v1.2.4  IMG_0000_1.tif           Blue                    475.0
# 1    v1.2.4  IMG_0000_1.tif           Blue                    475.0
# 2    v1.2.4  IMG_0000_1.tif           Blue                    475.0
# 3    v1.2.4  IMG_0000_1.tif           Blue                    475.0
# 4    v1.2.4  IMG_0000_1.tif           Blue                    475.0
#
#    Band0_CenterWavelength  Band0_WavelengthFWHM  ...  Band9_FileSuffix  \
# 0                   475.0                  32.0  ...            10.tif
# 1                   475.0                  32.0  ...            10.tif
# 2                   475.0                  32.0  ...            10.tif
# 3                   475.0                  32.0  ...            10.tif
# 4                   475.0                  32.0  ...            10.tif
#
#    Band10_FileSuffix Band1_FileSuffix Band2_FileSuffix Band3_FileSuffix  \
# 0             11.tif           _2.tif           _3.tif           _4.tif
# 1             11.tif           _2.tif           _3.tif           _4.tif
# 2             11.tif           _2.tif           _3.tif           _4.tif
# 3             11.tif           _2.tif           _3.tif           _4.tif
# 4             11.tif           _2.tif           _3.tif           _4.tif
#
#   Band4_FileSuffix  Band5_FileSuffix  Band6_FileSuffix  Band7_FileSuffix  \
# 0           _5.tif            _6.tif            _7.tif            _8.tif
# 1           _5.tif            _6.tif            _7.tif            _8.tif
# 2           _5.tif            _6.tif            _7.tif            _8.tif
# 3           _5.tif            _6.tif            _7.tif            _8.tif
# 4           _5.tif            _6.tif            _7.tif            _8.tif
#
#    Band8_FileSuffix
# 0            _9.tif
# 1            _9.tif
# 2            _9.tif
# 3            _9.tif
# 4            _9.tif
#
# [5 rows x 115 columns]

# %% [markdown]
# ## Step 3: Analyze Software Versions

# %%
# Count the occurrences of each software version
sw_versions = bands_df['Software'].value_counts()
print("Number of unique plots per firmware version:")
sw_versions
# Out:
# Number of unique plots per firmware version:
# Software
# v1.4.0    91
# v1.4.5    85
# v1.4.1    16
# v7.5.0    12
# v7.4.0     2
# Name: count, dtype: int64

# %% [markdown]
# ## Step 4: Compare Band Assignments Across Firmware Versions

# %%
# Compare band assignments across versions
comparison = plots.compare_band_assignments(bands_df)
# comparison

# %% [markdown]
# ## Step 5: Create a Compact Band Assignment Table

# %%
# Create a compact table showing band names by firmware version
band_table = plots.create_band_table(bands_df)
band_table
# Out:
# RigCameraIndex                0                 1                       10  \
# Software
# v1.4.0          Blue (475.0 nm)  Green (560.0 nm)  Red edge-740 (740.0 nm)
# v1.4.1          Blue (475.0 nm)  Green (560.0 nm)  Red edge-740 (740.0 nm)
# v1.4.5          Blue (475.0 nm)  Green (560.0 nm)  Red edge-705 (705.0 nm)
# v7.4.0          Blue (475.0 nm)  Green (560.0 nm)             nan (nan nm)
# v7.5.0          Blue (475.0 nm)  Green (560.0 nm)             nan (nan nm)
#
# RigCameraIndex               2               3                    4  \
# Software
# v1.4.0          Red (668.0 nm)  NIR (842.0 nm)  Red edge (717.0 nm)
# v1.4.1          Red (668.0 nm)  NIR (842.0 nm)  Red edge (717.0 nm)
# v1.4.5          Red (668.0 nm)  NIR (842.0 nm)  Red edge (717.0 nm)
# v7.4.0          Red (668.0 nm)  NIR (842.0 nm)  Red edge (717.0 nm)
# v7.5.0          Red (668.0 nm)  NIR (842.0 nm)  Red edge (717.0 nm)
#
# RigCameraIndex                    5                     6  \
# Software
# v1.4.0           Panchro (634.5 nm)   Blue-444 (444.0 nm)
# v1.4.1           Panchro (634.5 nm)   Blue-444 (444.0 nm)
# v1.4.5           Panchro (634.5 nm)   Blue-444 (444.0 nm)
# v7.4.0                 nan (nan nm)          nan (nan nm)
# v7.5.0          Blue-444 (444.0 nm)  Green-531 (531.0 nm)
#
# RigCameraIndex                     7                        8  \
# Software
# v1.4.0          Green-531 (531.0 nm)       Red-650 (650.0 nm)
# v1.4.1          Green-531 (531.0 nm)       Red-650 (650.0 nm)
# v1.4.5          Green-531 (531.0 nm)  Red edge-740 (740.0 nm)
# v7.4.0                  nan (nan nm)             nan (nan nm)
# v7.5.0            Red-650 (650.0 nm)  Red edge-705 (705.0 nm)
#
# RigCameraIndex                        9
# Software
# v1.4.0          Red edge-705 (705.0 nm)
# v1.4.1          Red edge-705 (705.0 nm)
# v1.4.5               Red-650 (650.0 nm)
# v7.4.0                     nan (nan nm)
# v7.5.0          Red edge-740 (740.0 nm)

# %% [markdown]
# ## Step 6: Find Specific Band Assignment Changes

# %%
# Identify where the same RigCameraIndex has different band names across versions
# Ignore specific software versions like v7.5.0
changed_assignments = []
ignore_versions = ['v7.5.0', 'v7.4.0']  # Add versions to ignore here

# Get unique RigCameraIndex values from the comparison DataFrame
band_indices = comparison['RigCameraIndex'].unique()

for idx in band_indices:
    # Filter out ignored software versions
    filtered_versions = comparison[(comparison['RigCameraIndex'] == idx) & 
                                  (~comparison['Software'].isin(ignore_versions))]
    
    unique_band_names = filtered_versions['BandName'].unique()
    
    if len(unique_band_names) > 1:
        print(f"RigCameraIndex {idx} has multiple band name assignments:")
        
        for _, row in filtered_versions.iterrows():
            # Get file name from bands_df for this RigCameraIndex and Software version
            version = row['Software']
            version_data = bands_df[bands_df['Software'] == version]
            
            # Find column name for the current band index
            filename_col = f"Band{idx}_FileName"
            
            # Get filename if it exists in the DataFrame
            if filename_col in version_data.columns:
                # Get the first non-null filename for this band and version
                example_file = version_data[filename_col].dropna().iloc[0] if not version_data[filename_col].dropna().empty else "Unknown"
                print(f"  Version {version}: {row['BandName']} ({row['CentralWavelength']} nm) - File: {example_file}")
            else:
                print(f"  Version {version}: {row['BandName']} ({row['CentralWavelength']} nm)")
        print()
        
        # Add to list of changes
        change_entry = {
            'RigCameraIndex': idx,
            'BandNames': list(unique_band_names),
            'Versions': list(filtered_versions['Software'])
        }
        
        # Add filenames from bands_df for each version
        file_names = []
        for version in filtered_versions['Software']:
            version_data = bands_df[bands_df['Software'] == version]
            filename_col = f"Band{idx}_FileName"
            
            if filename_col in version_data.columns:
                # Get the first non-null filename for this band and version
                example_file = version_data[filename_col].dropna().iloc[0] if not version_data[filename_col].dropna().empty else "Unknown"
                file_names.append(example_file)
            else:
                file_names.append("Unknown")
        
        change_entry['FileNames'] = file_names
        changed_assignments.append(change_entry)
# Out:
# RigCameraIndex 10 has multiple band name assignments:
#   Version v1.4.0: Red edge-740 (740.0 nm) - File: IMG_0000_11.tif
#   Version v1.4.1: Red edge-740 (740.0 nm) - File: IMG_0000_11.tif
#   Version v1.4.5: Red edge-705 (705.0 nm) - File: IMG_0000_11.tif
#
# RigCameraIndex 8 has multiple band name assignments:
#   Version v1.4.0: Red-650 (650.0 nm) - File: IMG_0000_9.tif
#   Version v1.4.1: Red-650 (650.0 nm) - File: IMG_0000_9.tif
#   Version v1.4.5: Red edge-740 (740.0 nm) - File: IMG_0000_9.tif
#
# RigCameraIndex 9 has multiple band name assignments:
#   Version v1.4.0: Red edge-705 (705.0 nm) - File: IMG_0000_10.tif
#   Version v1.4.1: Red edge-705 (705.0 nm) - File: IMG_0000_10.tif
#   Version v1.4.5: Red-650 (650.0 nm) - File: IMG_0000_10.tif

# %% [markdown]
# ## Step 7: Analyze Filename Patterns and Suffixes

# %%
# Analyze filename patterns for bands with changed assignments
print("Analyzing filename patterns for changed band assignments...\n")

for change in changed_assignments:
    idx = change['RigCameraIndex']
    band_names = change['BandNames']
    versions = change['Versions']
    file_names = change['FileNames']
    
    print(f"RigCameraIndex {idx}: {', '.join(band_names)}")
    
    # Compare filenames across versions
    unique_filenames = set(file_names)
    if len(unique_filenames) > 1:
        print(f"  Different filename patterns detected across versions:")
        for version, filename in zip(versions, file_names):
            print(f"    Version {version}: {filename}")
    else:
        print(f"  Same filename pattern across all versions: {next(iter(unique_filenames))}")
        
    # Look for file suffix patterns in the raw data
    suffix_patterns = {}
    for version in versions:
        version_data = bands_df[bands_df['Software'] == version]
        suffix_col = f"Band{idx}_FileSuffix"
        
        if suffix_col in version_data.columns:
            suffixes = version_data[suffix_col].dropna().unique()
            suffix_patterns[version] = list(suffixes) if len(suffixes) > 0 else ["Unknown"]
    
    # Check if there are different suffix patterns across versions
    all_suffixes = set()
    for suffixes in suffix_patterns.values():
        all_suffixes.update(suffixes)
        
    if len(all_suffixes) > 1 or len(suffix_patterns) > 0:
        print("  File suffix patterns:")
        for version, suffixes in suffix_patterns.items():
            print(f"    Version {version}: {', '.join(suffixes)}")
    else:
        print("  No file suffix patterns found")
    
    # Check for filename structure consistency
    filename_structures = {}
    for version in versions:
        version_data = bands_df[bands_df['Software'] == version]
        filename_col = f"Band{idx}_FileName"
        
        if filename_col in version_data.columns:
            filenames = version_data[filename_col].dropna()
            if not filenames.empty:
                # Extract the base part of the filename (before index)
                base_parts = set()
                for fname in filenames:
                    # Try to extract consistent parts of the filename before the index
                    parts = fname.split(f"_{idx}")
                    if len(parts) > 1:
                        base_parts.add(parts[0])
                
                filename_structures[version] = list(base_parts)
    
    if filename_structures:
        print("  Filename base structures:")
        for version, structures in filename_structures.items():
            print(f"    Version {version}: {', '.join(structures)}")
    
    print()
# Out:
# Analyzing filename patterns for changed band assignments...
#
# RigCameraIndex 10: Red edge-740, Red edge-705
#   Same filename pattern across all versions: IMG_0000_11.tif
#   File suffix patterns:
#     Version v1.4.0: 11.tif
#     Version v1.4.1: 11.tif
#     Version v1.4.5: 11.tif
#   Filename base structures:
#     Version v1.4.0:
#     Version v1.4.1:
#     Version v1.4.5:
#
# RigCameraIndex 8: Red-650, Red edge-740
#   Same filename pattern across all versions: IMG_0000_9.tif
#   File suffix patterns:
#     Version v1.4.0: _9.tif
#     Version v1.4.1: _9.tif
#     Version v1.4.5: _9.tif
#   Filename base structures:
#     Version v1.4.0:
#     Version v1.4.1:
#     Version v1.4.5:
#
# RigCameraIndex 9: Red edge-705, Red-650
#   Same filename pattern across all versions: IMG_0000_10.tif
#   File suffix patterns:
#     Version v1.4.0: 10.tif
#     Version v1.4.1: 10.tif
#     Version v1.4.5: 10.tif
#   Filename base structures:
#     Version v1.4.0:
#     Version v1.4.1:
#     Version v1.4.5:

# %% [markdown]
# ## Step 8: Get a list of plots with specific firmware version

# %%
# Get a list of plots with specific firmware version
def get_plots_with_version(df, version):
    return df[df['Software'] == version][['plot_id', 'visit_date']].sort_values('plot_id')

# Example - change 'v1.2.4' to the version you're interested in
target_version = bands_df['Software'].unique()[0]  # Just taking the first version as an example
print(f"Plots with firmware version {target_version}:")
# to_update = get_plots_with_version(bands_df, target_version)
# Out:
# Plots with firmware version v1.4.0:

# %%
target_dirs = to_update.plot_id.values.tolist()

# %%
target_dirs[1:5]
# Out:
# ['NTABRT0002', 'NTABRT0003', 'NTABRT0004', 'NTABRT0005']

# %% [markdown]
# ## Final Step:Export the results

# %%
# Export the comparison table to CSV
# comparison.to_csv('band_comparison.csv', index=False)

# Export the compact band table
# band_table.to_csv('band_table_by_version.csv')

# Export the bands_df
bands_df.to_clipboard()
# bands_df.to_csv('bands_df.csv', index=False)
